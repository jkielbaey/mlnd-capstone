# %% [markdown]
# # Higgs Boson - Collision event classification
#
# ## Model creation

# %% [markdown]
# ### Upload data to S3
#
# The data files have already been prepared locally on the storage of the Sagemaker Notebook instance. Next we'll upload them onto the default S3 bucket

# %%
# import libraries
import pandas as pd
import numpy as np

from sklearn.metrics import accuracy_score, recall_score, roc_auc_score

import os
import time
import boto3
import sagemaker
from sagemaker import get_execution_role

# %%
# SageMaker session and role
LOCAL_MODE = False
if LOCAL_MODE:
    # During model development it's more efficient to use SageMaker local model.
    # https://aws.amazon.com/blogs/machine-learning/use-the-amazon-sagemaker-local-mode-to-train-on-your-notebook-instance/
    sagemaker_session = sagemaker.LocalSession()

    # If notebook instance does not have GPUs, change to 'local'.
    train_instance_type = 'local_gpu'
    deploy_instance_type = 'local_gpu'
    print('Running in local mode.')
else:
    sagemaker_session = sagemaker.Session()
    train_instance_type = 'ml.m5.xlarge'
    deploy_instance_type = 'ml.m5.large'
    print('Running in remote mode.')

role = sagemaker.get_execution_role()

# Use the default Sagemaker an S3 bucket
bucket = sagemaker_session.default_bucket()

# Prefix for objects in S3 bucket
prefix = 'capstone/xgb_500000'

# Location of data files on notebook storage.
data_dir = '../data/500000'
# Out:
# Running in remote mode.

# %%
# Actual upload of the data files.
train_path = sagemaker_session.upload_data(data_dir+'/train.csv', bucket=bucket, key_prefix=prefix)
val_path = sagemaker_session.upload_data(data_dir+'/val.csv', bucket=bucket, key_prefix=prefix)

s3_input_train = sagemaker.s3_input(s3_data=train_path, content_type='csv')
s3_input_val = sagemaker.s3_input(s3_data=val_path, content_type='csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
# Read the test data.
test_df = pd.read_csv(os.path.join(data_dir, 'test.csv'), header=None)
print("Shape: {}".format(test_df.shape))

# Seperate labels and features
test_y = test_df.iloc[:,0]
test_X = test_df.iloc[:, 1:]

# Dump the test features and upload to S3.
test_file = 'test-2.csv'
pd.DataFrame(test_X).to_csv(os.path.join(data_dir, test_file), header=False, index=False)
test_path = sagemaker_session.upload_data(os.path.join(data_dir, test_file), bucket=bucket, key_prefix=prefix)
print(test_path)
# Out:
# Shape: (75000, 18)
# s3://sagemaker-eu-west-1-019518462631/capstone/xgb_500000/test-2.csv

# %%
# Check if files have been uploaded
for obj in boto3.resource('s3').Bucket(bucket).objects.all():
    if prefix in obj.key and '.csv' in obj.key:
        print(obj.key)
# Out:
# capstone/xgb_500000/test-2.csv
# capstone/xgb_500000/train.csv
# capstone/xgb_500000/val.csv

# %% [markdown]
# ### Test model using XGBoost
#
# Initially let's explore how well a SageMaker built-in algorithm performs on the dataset.
# First a model is trained using basic parameters. Next hyper parameter tuning is applied to see how much it can be improved.

# %% [markdown]
# #### Initial XGBoost model

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri

# Use the latest xgboost algorithm.
container = get_image_uri(sagemaker_session.boto_region_name,
                          'xgboost',
                          repo_version='1.0-1')


# Create an estimator and set the hyper parameters.
xgb_output_path = 's3://{}/{}/output'.format(bucket, prefix)
xgb = sagemaker.estimator.Estimator(container,
                                    role,
                                    train_instance_count=1,
                                    train_instance_type=train_instance_type,
                                    output_path=xgb_output_path,
                                    sagemaker_session=sagemaker_session)

xgb.set_hyperparameters(eval_metric='auc',
                        objective='binary:logistic',
                        max_depth=10,
                        num_round=500,
                        eta=0.2,
                        gamma=4,
                        rate_drop=0.3,
                        min_child_weight=6,
                        subsample=0.8,
                        early_stopping_rounds=15,
                        tweedie_variance_power=1.4)
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# WARNING:root:Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %%
# %%time

# Do actual training.
xgb.fit({'train': s3_input_train, 'validation': s3_input_val})
# Out:
# 2020-07-19 09:47:45 Starting - Starting the training job...
# 2020-07-19 09:47:47 Starting - Launching requested ML instances......
# 2020-07-19 09:48:53 Starting - Preparing the instances for training...
# 2020-07-19 09:49:41 Downloading - Downloading input data
# 2020-07-19 09:49:41 Training - Downloading the training image...
# 2020-07-19 09:50:10 Training - Training image download completed. Training in progress......INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter eval_metric value auc to Json.
# Returning the value itself
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# [09:50:13] 350000x17 matrix with 5950000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# INFO:root:Determined delimiter of CSV input is ','
# [09:50:13] 75000x17 matrix with 1275000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# INFO:root:Single node training.
# INFO:root:Train matrix has 350000 rows
# INFO:root:Validation matrix has 75000 rows
# [0]#011train-auc:0.67721#011validation-auc:0.65416
# [1]#011train-auc:0.68752#011validation-auc:0.66194
# [2]#011train-auc:0.69535#011validation-auc:0.66863
# [3]#011train-auc:0.70014#011validation-auc:0.67266
# [4]#011train-auc:0.70591#011validation-auc:0.67566
# [5]#011train-auc:0.71030#011validation-auc:0.67813
# [6]#011train-auc:0.71569#011validation-auc:0.68100
# [7]#011train-auc:0.71891#011validation-auc:0.68267
# [8]#011train-auc:0.72202#011validation-auc:0.68376
# [9]#011train-auc:0.72500#011validation-auc:0.68590
# [10]#011train-auc:0.73147#011validation-auc:0.68999
# [11]#011train-auc:0.73455#011validation-auc:0.69147
# [12]#011train-auc:0.74069#011validation-auc:0.69459
# [13]#011train-auc:0.74618#011validation-auc:0.69686
# [14]#011train-auc:0.74730#011validation-auc:0.69740
# [15]#011train-auc:0.75149#011validation-auc:0.69894
# [16]#011train-auc:0.75709#011validation-auc:0.70136
# [17]#011train-auc:0.75821#011validation-auc:0.70173
# [18]#011train-auc:0.76124#011validation-auc:0.70364
# [19]#011train-auc:0.76332#011validation-auc:0.70471
# [20]#011train-auc:0.76528#011validation-auc:0.70550
# [21]#011train-auc:0.76752#011validation-auc:0.70638
# [22]#011train-auc:0.76857#011validation-auc:0.70664
# [23]#011train-auc:0.77045#011validation-auc:0.70716
# [24]#011train-auc:0.77202#011validation-auc:0.70766
# [25]#011train-auc:0.77443#011validation-auc:0.70875
# [26]#011train-auc:0.77548#011validation-auc:0.70901
# [27]#011train-auc:0.77829#011validation-auc:0.71016
# [28]#011train-auc:0.77878#011validation-auc:0.71027
# [29]#011train-auc:0.77931#011validation-auc:0.71043
# [30]#011train-auc:0.78051#011validation-auc:0.71049
# [31]#011train-auc:0.78248#011validation-auc:0.71112
# [32]#011train-auc:0.78580#011validation-auc:0.71220
# [33]#011train-auc:0.78650#011validation-auc:0.71231
# [34]#011train-auc:0.78708#011validation-auc:0.71251
# [35]#011train-auc:0.78895#011validation-auc:0.71300
# [36]#011train-auc:0.78932#011validation-auc:0.71305
# [37]#011train-auc:0.78978#011validation-auc:0.71318
# [38]#011train-auc:0.79118#011validation-auc:0.71371
# [39]#011train-auc:0.79214#011validation-auc:0.71409
# [40]#011train-auc:0.79304#011validation-auc:0.71408
# [41]#011train-auc:0.79400#011validation-auc:0.71419
# [42]#011train-auc:0.79555#011validation-auc:0.71439
# [43]#011train-auc:0.79572#011validation-auc:0.71435
# [44]#011train-auc:0.79601#011validation-auc:0.71441
# [45]#011train-auc:0.79658#011validation-auc:0.71449
# [46]#011train-auc:0.79878#011validation-auc:0.71500
# [47]#011train-auc:0.79906#011validation-auc:0.71503
# [48]#011train-auc:0.79946#011validation-auc:0.71510
# [49]#011train-auc:0.80003#011validation-auc:0.71518
# [50]#011train-auc:0.80016#011validation-auc:0.71520
# [51]#011train-auc:0.80058#011validation-auc:0.71527
# [52]#011train-auc:0.80234#011validation-auc:0.71640
# [53]#011train-auc:0.80280#011validation-auc:0.71642
# [54]#011train-auc:0.80296#011validation-auc:0.71643
# [55]#011train-auc:0.80313#011validation-auc:0.71641
# [56]#011train-auc:0.80454#011validation-auc:0.71683
# [57]#011train-auc:0.80502#011validation-auc:0.71676
# [58]#011train-auc:0.80540#011validation-auc:0.71670
# [59]#011train-auc:0.80651#011validation-auc:0.71688
# [60]#011train-auc:0.80760#011validation-auc:0.71708
# [61]#011train-auc:0.80834#011validation-auc:0.71726
# [62]#011train-auc:0.80913#011validation-auc:0.71719
# [63]#011train-auc:0.80957#011validation-auc:0.71730
# [64]#011train-auc:0.81053#011validation-auc:0.71733
# [65]#011train-auc:0.81095#011validation-auc:0.71728
# [66]#011train-auc:0.81129#011validation-auc:0.71719
# [67]#011train-auc:0.81197#011validation-auc:0.71720
# [68]#011train-auc:0.81238#011validation-auc:0.71734
# [69]#011train-auc:0.81412#011validation-auc:0.71747
# [70]#011train-auc:0.81447#011validation-auc:0.71753
# [71]#011train-auc:0.81462#011validation-auc:0.71757
# [72]#011train-auc:0.81554#011validation-auc:0.71753
# [73]#011train-auc:0.81584#011validation-auc:0.71740
# [74]#011train-auc:0.81622#011validation-auc:0.71740
# [75]#011train-auc:0.81711#011validation-auc:0.71738
# [76]#011train-auc:0.81783#011validation-auc:0.71735
# [77]#011train-auc:0.81922#011validation-auc:0.71779
# [78]#011train-auc:0.81994#011validation-auc:0.71775
# [79]#011train-auc:0.82017#011validation-auc:0.71768
# [80]#011train-auc:0.82070#011validation-auc:0.71762
# [81]#011train-auc:0.82182#011validation-auc:0.71777
# [82]#011train-auc:0.82194#011validation-auc:0.71776
# [83]#011train-auc:0.82264#011validation-auc:0.71775
# [84]#011train-auc:0.82308#011validation-auc:0.71770
# [85]#011train-auc:0.82394#011validation-auc:0.71793
# [86]#011train-auc:0.82491#011validation-auc:0.71786
# [87]#011train-auc:0.82570#011validation-auc:0.71789
# [88]#011train-auc:0.82618#011validation-auc:0.71836
# [89]#011train-auc:0.82645#011validation-auc:0.71833
# [90]#011train-auc:0.82757#011validation-auc:0.71824
# [91]#011train-auc:0.82813#011validation-auc:0.71828
# [92]#011train-auc:0.82867#011validation-auc:0.71828
# [93]#011train-auc:0.82901#011validation-auc:0.71823
# [94]#011train-auc:0.82947#011validation-auc:0.71818
# [95]#011train-auc:0.82969#011validation-auc:0.71812
# [96]#011train-auc:0.82992#011validation-auc:0.71812
# [97]#011train-auc:0.83048#011validation-auc:0.71811
# [98]#011train-auc:0.83056#011validation-auc:0.71813
# [99]#011train-auc:0.83136#011validation-auc:0.71805
# [100]#011train-auc:0.83230#011validation-auc:0.71822
# [101]#011train-auc:0.83389#011validation-auc:0.71910
# [102]#011train-auc:0.83420#011validation-auc:0.71901
# [103]#011train-auc:0.83498#011validation-auc:0.71907
# [104]#011train-auc:0.83536#011validation-auc:0.71903
# [105]#011train-auc:0.83563#011validation-auc:0.71914
# [106]#011train-auc:0.83627#011validation-auc:0.71918
# [107]#011train-auc:0.83663#011validation-auc:0.71909
# [108]#011train-auc:0.83712#011validation-auc:0.71890
# [109]#011train-auc:0.83766#011validation-auc:0.71906
# [110]#011train-auc:0.83805#011validation-auc:0.71906
# [111]#011train-auc:0.83826#011validation-auc:0.71903
# [112]#011train-auc:0.83851#011validation-auc:0.71901
# [113]#011train-auc:0.83873#011validation-auc:0.71898
# [114]#011train-auc:0.83939#011validation-auc:0.71891
# [115]#011train-auc:0.84001#011validation-auc:0.71881
# [116]#011train-auc:0.84020#011validation-auc:0.71880
# [117]#011train-auc:0.84054#011validation-auc:0.71880
# [118]#011train-auc:0.84096#011validation-auc:0.71876
# [119]#011train-auc:0.84151#011validation-auc:0.71885
# [120]#011train-auc:0.84207#011validation-auc:0.71893
# [121]#011train-auc:0.84244#011validation-auc:0.71891
#
# 2020-07-19 09:51:32 Uploading - Uploading generated training model
# 2020-07-19 09:51:32 Completed - Training job completed
# Training seconds: 126
# Billable seconds: 126
# CPU times: user 517 ms, sys: 26.6 ms, total: 543 ms
# Wall time: 4min 12s

# %% [markdown]
# During training the AUC score on the validation set increased from an initial score of 0.65416 to **0.71918** (highest value on round 106). The number of rounds was set to 500 but training ended after 120 rounds, which means that given with the current data and settings for hyper parameters, training reached a plateau.

# %%
# %%time

# After training, I evaluate the model using the test data...
xgb_transformer = xgb.transformer(instance_count = 1, instance_type = 'ml.m5.large')
xgb_transformer.transform(test_path, content_type='text/csv', split_type='Line')
xgb_transformer.wait()

# The output of the transform job is downloaded back onto the notebook...
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir

# And the predictions are processed and metrics calculated.
predictions = pd.read_csv(os.path.join(data_dir, 'test-2.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

print("Accuracy: {:4f}".format(accuracy_score(test_y, predictions)))
print("Recal:    {:4f}".format(recall_score(test_y, predictions)))
print("ROC AUC:  {:4f}".format(roc_auc_score(test_y, predictions)))
# Out:
# WARNING:sagemaker:Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# ...................[2020-07-19:09:54:52:INFO] No GPUs detected (normal if no gpus installed)
# [2020-07-19:09:54:52:INFO] No GPUs detected (normal if no gpus installed)
# [2020-07-19:09:54:52:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# [2020-07-19 09:54:52 +0000] [13] [INFO] Starting gunicorn 19.10.0
# [2020-07-19 09:54:52 +0000] [13] [INFO] Listening at: unix:/tmp/gunicorn.sock (13)
# [2020-07-19 09:54:52 +0000] [13] [INFO] Using worker: gevent
# [2020-07-19 09:54:52 +0000] [18] [INFO] Booting worker with pid: 18
# [2020-07-19 09:54:52 +0000] [19] [INFO] Booting worker with pid: 19
# [2020-07-19:09:55:04:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [19/Jul/2020:09:55:04 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2020-07-19:09:55:04:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [19/Jul/2020:09:55:04 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2020-07-19:09:55:04:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [19/Jul/2020:09:55:04 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2020-07-19:09:55:04:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [19/Jul/2020:09:55:04 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2020-07-19:09:55:06:INFO] Determined delimiter of CSV input is ','
# [2020-07-19:09:55:06:INFO] Determined delimiter of CSV input is ','
# [2020-07-19:09:55:06:INFO] Determined delimiter of CSV input is ','
# [2020-07-19:09:55:06:INFO] Determined delimiter of CSV input is ','
# 2020-07-19T09:55:04.986:[sagemaker logs]: MaxConcurrentTransforms=2, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# 169.254.255.130 - - [19/Jul/2020:09:55:07 +0000] "POST /invocations HTTP/1.1" 200 361846 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [19/Jul/2020:09:55:07 +0000] "POST /invocations HTTP/1.1" 200 361880 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [19/Jul/2020:09:55:07 +0000] "POST /invocations HTTP/1.1" 200 361846 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [19/Jul/2020:09:55:07 +0000] "POST /invocations HTTP/1.1" 200 361880 "-" "Go-http-client/1.1"
# [2020-07-19:09:55:07:INFO] Determined delimiter of CSV input is ','
# [2020-07-19:09:55:07:INFO] Determined delimiter of CSV input is ','
# [2020-07-19:09:55:07:INFO] Determined delimiter of CSV input is ','
# [2020-07-19:09:55:07:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [19/Jul/2020:09:55:08 +0000] "POST /invocations HTTP/1.1" 200 349835 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [19/Jul/2020:09:55:08 +0000] "POST /invocations HTTP/1.1" 200 361790 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [19/Jul/2020:09:55:08 +0000] "POST /invocations HTTP/1.1" 200 349835 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [19/Jul/2020:09:55:08 +0000] "POST /invocations HTTP/1.1" 200 361790 "-" "Go-http-client/1.1"
#
# download: s3://sagemaker-eu-west-1-019518462631/sagemaker-xgboost-2020-07-19-09-51-57-395/test-2.csv.out to ../data/500000/test-2.csv.out
# Accuracy: 0.666027
# Recal:    0.718001
# ROC AUC:  0.662989
# CPU times: user 711 ms, sys: 40.5 ms, total: 752 ms
# Wall time: 3min 43s

# %% [markdown]
# With minimal effort and using the built-in XGBoost algorithm, an AUC score of **0.662989** on the test set was obtained.

# %% [markdown]
# #### Optimized model
#
# Next a new model is created and hyper parameter tuning is applied to it.

# %%
from sagemaker.tuner import IntegerParameter, CategoricalParameter, ContinuousParameter, HyperparameterTuner

xgb_output_path = 's3://{}/{}/output'.format(bucket, prefix)

xgb_estimator = sagemaker.estimator.Estimator(container,
                                              role,
                                              train_instance_count=1,
                                              train_instance_type=train_instance_type,
                                              output_path=xgb_output_path,
                                              sagemaker_session=sagemaker_session)

xgb_estimator.set_hyperparameters(eval_metric='auc',
                                  objective='binary:logistic',
                                  num_round=500,
                                  rate_drop=0.3,
                                  early_stopping_rounds=15,
                                  tweedie_variance_power=1.4)

hyperparameter_ranges = {
    'eta': ContinuousParameter(0, 1),
    'min_child_weight': ContinuousParameter(1, 10),
    'alpha': ContinuousParameter(0, 2),
    'eta': ContinuousParameter(0, 1),
    'gamma': ContinuousParameter(0, 10),
    'max_depth': IntegerParameter(1, 20),
    'subsample': ContinuousParameter(0, 1)
}

objective_metric_name = 'validation:auc'

xgb_tuner = HyperparameterTuner(xgb_estimator,
                                objective_metric_name,
                                hyperparameter_ranges,
                                max_jobs=30,
                                max_parallel_jobs=4)
# Out:
# WARNING:root:Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %%
# %%time

import time

xgb_tuner.fit({'train': s3_input_train, 'validation': s3_input_val})

xgb_tuning_job_info = sagemaker_session.sagemaker_client.describe_hyper_parameter_tuning_job(HyperParameterTuningJobName=xgb_tuner.latest_tuning_job.job_name)

# Wait while hyperparameter tuning job is running.
while xgb_tuning_job_info['HyperParameterTuningJobStatus'] == 'InProgress':
    print("JobStatus: {}".format(xgb_tuning_job_info['TrainingJobStatusCounters']))
    print("ObjectiveStatus: {}".format(xgb_tuning_job_info['ObjectiveStatusCounters']))
    time.sleep(5*60)
    xgb_tuning_job_info = sagemaker_session.sagemaker_client.describe_hyper_parameter_tuning_job(HyperParameterTuningJobName=xgb_tuner.latest_tuning_job.job_name)
# Out:
# JobStatus: {'Completed': 0, 'InProgress': 0, 'RetryableError': 0, 'NonRetryableError': 0, 'Stopped': 0}
# ObjectiveStatus: {'Succeeded': 0, 'Pending': 0, 'Failed': 0}
# JobStatus: {'Completed': 3, 'InProgress': 4, 'RetryableError': 0, 'NonRetryableError': 0, 'Stopped': 0}
# ObjectiveStatus: {'Succeeded': 3, 'Pending': 4, 'Failed': 0}
# JobStatus: {'Completed': 8, 'InProgress': 4, 'RetryableError': 0, 'NonRetryableError': 0, 'Stopped': 0}
# ObjectiveStatus: {'Succeeded': 8, 'Pending': 4, 'Failed': 0}
# JobStatus: {'Completed': 10, 'InProgress': 4, 'RetryableError': 0, 'NonRetryableError': 0, 'Stopped': 0}
# ObjectiveStatus: {'Succeeded': 10, 'Pending': 4, 'Failed': 0}
# JobStatus: {'Completed': 13, 'InProgress': 4, 'RetryableError': 0, 'NonRetryableError': 0, 'Stopped': 0}
# ObjectiveStatus: {'Succeeded': 13, 'Pending': 4, 'Failed': 0}
# JobStatus: {'Completed': 15, 'InProgress': 3, 'RetryableError': 0, 'NonRetryableError': 0, 'Stopped': 0}
# ObjectiveStatus: {'Succeeded': 15, 'Pending': 3, 'Failed': 0}
# JobStatus: {'Completed': 18, 'InProgress': 4, 'RetryableError': 0, 'NonRetryableError': 0, 'Stopped': 0}
# ObjectiveStatus: {'Succeeded': 18, 'Pending': 4, 'Failed': 0}
# JobStatus: {'Completed': 20, 'InProgress': 4, 'RetryableError': 0, 'NonRetryableError': 1, 'Stopped': 0}
# ObjectiveStatus: {'Succeeded': 20, 'Pending': 4, 'Failed': 1}
# JobStatus: {'Completed': 24, 'InProgress': 4, 'RetryableError': 0, 'NonRetryableError': 1, 'Stopped': 0}
# ObjectiveStatus: {'Succeeded': 24, 'Pending': 4, 'Failed': 1}
# JobStatus: {'Completed': 25, 'InProgress': 4, 'RetryableError': 0, 'NonRetryableError': 1, 'Stopped': 0}
# ObjectiveStatus: {'Succeeded': 25, 'Pending': 4, 'Failed': 1}
# CPU times: user 248 ms, sys: 51 ms, total: 299 ms
# Wall time: 50min 1s

# %%
# %%time

xgb_best_estimator = xgb_tuner.best_estimator()

xgb_best_transformer = xgb_best_estimator.transformer(instance_count = 1, instance_type = 'ml.m5.large')
xgb_best_transformer.transform(test_path, content_type='text/csv', split_type='Line')
xgb_best_transformer.wait()

# !aws s3 cp --recursive $xgb_best_transformer.output_path $data_dir

# And the predictions are processed and metrics calculated.
predictions = pd.read_csv(os.path.join(data_dir, 'test-2.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

print("Accuracy: {:4f}".format(accuracy_score(test_y, predictions)))
print("Recal:    {:4f}".format(recall_score(test_y, predictions)))
print("ROC AUC:  {:4f}".format(roc_auc_score(test_y, predictions)))
# Out:
# WARNING:root:Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 2020-07-19 10:29:09 Starting - Preparing the instances for training
# 2020-07-19 10:29:09 Downloading - Downloading input data
# 2020-07-19 10:29:09 Training - Training image download completed. Training in progress.
# 2020-07-19 10:29:09 Uploading - Uploading generated training model
# 2020-07-19 10:29:09 Completed - Training job completed
# WARNING:sagemaker:Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter eval_metric value auc to Json.
# Returning the value itself
# INFO:sagemaker-containers:Failed to parse hyperparameter _tuning_objective_metric value validation:auc to Json.
# Returning the value itself
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# [10:20:52] 350000x17 matrix with 5950000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# INFO:root:Determined delimiter of CSV input is ','
# [10:20:52] 75000x17 matrix with 1275000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# INFO:root:Single node training.
# INFO:root:Setting up HPO optimized metric to be : auc
# INFO:root:Train matrix has 350000 rows
# INFO:root:Validation matrix has 75000 rows
# [0]#011train-auc:0.70186#011validation-auc:0.66363
# [1]#011train-auc:0.71679#011validation-auc:0.67468
# [2]#011train-auc:0.72415#011validation-auc:0.67941
# [3]#011train-auc:0.72738#011validation-auc:0.68149
# [4]#011train-auc:0.73102#011validation-auc:0.68341
# [5]#011train-auc:0.73540#011validation-auc:0.68633
# [6]#011train-auc:0.73784#011validation-auc:0.68805
# [7]#011train-auc:0.74102#011validation-auc:0.68994
# [8]#011train-auc:0.74325#011validation-auc:0.69164
# [9]#011train-auc:0.74536#011validation-auc:0.69286
# [10]#011train-auc:0.74695#011validation-auc:0.69373
# [11]#011train-auc:0.74930#011validation-auc:0.69514
# [12]#011train-auc:0.75177#011validation-auc:0.69629
# [13]#011train-auc:0.75395#011validation-auc:0.69737
# [14]#011train-auc:0.75583#011validation-auc:0.69819
# [15]#011train-auc:0.75771#011validation-auc:0.69908
# [16]#011train-auc:0.75932#011validation-auc:0.69990
# [17]#011train-auc:0.76083#011validation-auc:0.70049
# [18]#011train-auc:0.76255#011validation-auc:0.70114
# [19]#011train-auc:0.76448#011validation-auc:0.70225
# [20]#011train-auc:0.76617#011validation-auc:0.70305
# [21]#011train-auc:0.76823#011validation-auc:0.70416
# [22]#011train-auc:0.77001#011validation-auc:0.70499
# [23]#011train-auc:0.77213#011validation-auc:0.70625
# [24]#011train-auc:0.77407#011validation-auc:0.70731
# [25]#011train-auc:0.77605#011validation-auc:0.70854
# [26]#011train-auc:0.77743#011validation-auc:0.70946
# [27]#011train-auc:0.77893#011validation-auc:0.71042
# [28]#011train-auc:0.78009#011validation-auc:0.71098
# [29]#011train-auc:0.78164#011validation-auc:0.71186
# [30]#011train-auc:0.78263#011validation-auc:0.71233
# [31]#011train-auc:0.78320#011validation-auc:0.71275
# [32]#011train-auc:0.78402#011validation-auc:0.71313
# [33]#011train-auc:0.78552#011validation-auc:0.71408
# [34]#011train-auc:0.78715#011validation-auc:0.71538
# [35]#011train-auc:0.78781#011validation-auc:0.71585
# [36]#011train-auc:0.78880#011validation-auc:0.71642
# [37]#011train-auc:0.78995#011validation-auc:0.71698
# [38]#011train-auc:0.79104#011validation-auc:0.71752
# [39]#011train-auc:0.79149#011validation-auc:0.71784
# [40]#011train-auc:0.79227#011validation-auc:0.71819
# [41]#011train-auc:0.79327#011validation-auc:0.71847
# [42]#011train-auc:0.79387#011validation-auc:0.71879
# [43]#011train-auc:0.79443#011validation-auc:0.71918
# [44]#011train-auc:0.79461#011validation-auc:0.71937
# [45]#011train-auc:0.79563#011validation-auc:0.71987
# [46]#011train-auc:0.79617#011validation-auc:0.72005
# [47]#011train-auc:0.79689#011validation-auc:0.72040
# [48]#011train-auc:0.79785#011validation-auc:0.72101
# [49]#011train-auc:0.79875#011validation-auc:0.72170
# [50]#011train-auc:0.79904#011validation-auc:0.72181
# [51]#011train-auc:0.79951#011validation-auc:0.72201
# [52]#011train-auc:0.79995#011validation-auc:0.72227
# [53]#011train-auc:0.80074#011validation-auc:0.72265
# [54]#011train-auc:0.80111#011validation-auc:0.72264
# [55]#011train-auc:0.80169#011validation-auc:0.72320
# [56]#011train-auc:0.80184#011validation-auc:0.72325
# [57]#011train-auc:0.80191#011validation-auc:0.72327
# [58]#011train-auc:0.80219#011validation-auc:0.72343
# [59]#011train-auc:0.80265#011validation-auc:0.72362
# [60]#011train-auc:0.80301#011validation-auc:0.72378
# [61]#011train-auc:0.80370#011validation-auc:0.72423
# [62]#011train-auc:0.80412#011validation-auc:0.72447
# [63]#011train-auc:0.80440#011validation-auc:0.72454
# [64]#011train-auc:0.80483#011validation-auc:0.72481
# [65]#011train-auc:0.80486#011validation-auc:0.72479
# [66]#011train-auc:0.80528#011validation-auc:0.72492
# [67]#011train-auc:0.80537#011validation-auc:0.72496
# [68]#011train-auc:0.80572#011validation-auc:0.72518
# [69]#011train-auc:0.80588#011validation-auc:0.72524
# [70]#011train-auc:0.80614#011validation-auc:0.72531
# [71]#011train-auc:0.80633#011validation-auc:0.72534
# [72]#011train-auc:0.80692#011validation-auc:0.72555
# [73]#011train-auc:0.80713#011validation-auc:0.72557
# [74]#011train-auc:0.80736#011validation-auc:0.72566
# [75]#011train-auc:0.80745#011validation-auc:0.72569
# [76]#011train-auc:0.80827#011validation-auc:0.72606
# [77]#011train-auc:0.80851#011validation-auc:0.72608
# [78]#011train-auc:0.80870#011validation-auc:0.72607
# [79]#011train-auc:0.80904#011validation-auc:0.72615
# [80]#011train-auc:0.80909#011validation-auc:0.72615
# [81]#011train-auc:0.80947#011validation-auc:0.72653
# [82]#011train-auc:0.80990#011validation-auc:0.72660
# [83]#011train-auc:0.81031#011validation-auc:0.72666
# [84]#011train-auc:0.81037#011validation-auc:0.72667
# [85]#011train-auc:0.81083#011validation-auc:0.72684
# [86]#011train-auc:0.81092#011validation-auc:0.72687
# [87]#011train-auc:0.81133#011validation-auc:0.72702
# [88]#011train-auc:0.81142#011validation-auc:0.72703
# [89]#011train-auc:0.81153#011validation-auc:0.72706
# [90]#011train-auc:0.81205#011validation-auc:0.72712
# [91]#011train-auc:0.81271#011validation-auc:0.72744
# [92]#011train-auc:0.81285#011validation-auc:0.72748
# [93]#011train-auc:0.81304#011validation-auc:0.72758
# [94]#011train-auc:0.81314#011validation-auc:0.72760
# [95]#011train-auc:0.81349#011validation-auc:0.72770
# [96]#011train-auc:0.81393#011validation-auc:0.72779
# [97]#011train-auc:0.81400#011validation-auc:0.72779
# [98]#011train-auc:0.81406#011validation-auc:0.72780
# [99]#011train-auc:0.81412#011validation-auc:0.72780
# [100]#011train-auc:0.81420#011validation-auc:0.72778
# [101]#011train-auc:0.81437#011validation-auc:0.72783
# [102]#011train-auc:0.81451#011validation-auc:0.72790
# [103]#011train-auc:0.81465#011validation-auc:0.72790
# [104]#011train-auc:0.81476#011validation-auc:0.72793
# [105]#011train-auc:0.81496#011validation-auc:0.72799
# [106]#011train-auc:0.81519#011validation-auc:0.72802
# [107]#011train-auc:0.81534#011validation-auc:0.72803
# [108]#011train-auc:0.81539#011validation-auc:0.72803
# [109]#011train-auc:0.81573#011validation-auc:0.72803
# [110]#011train-auc:0.81591#011validation-auc:0.72803
# [111]#011train-auc:0.81601#011validation-auc:0.72805
# [112]#011train-auc:0.81611#011validation-auc:0.72804
# [113]#011train-auc:0.81620#011validation-auc:0.72805
# [114]#011train-auc:0.81642#011validation-auc:0.72807
# [115]#011train-auc:0.81714#011validation-auc:0.72820
# [116]#011train-auc:0.81730#011validation-auc:0.72827
# [117]#011train-auc:0.81732#011validation-auc:0.72827
# [118]#011train-auc:0.81787#011validation-auc:0.72850
# [119]#011train-auc:0.81810#011validation-auc:0.72857
# [120]#011train-auc:0.81839#011validation-auc:0.72868
# [121]#011train-auc:0.81846#011validation-auc:0.72869
# [122]#011train-auc:0.81848#011validation-auc:0.72868
# [123]#011train-auc:0.81863#011validation-auc:0.72887
# [124]#011train-auc:0.81886#011validation-auc:0.72895
# [125]#011train-auc:0.81895#011validation-auc:0.72899
# [126]#011train-auc:0.81907#011validation-auc:0.72900
# [127]#011train-auc:0.81908#011validation-auc:0.72901
# [128]#011train-auc:0.81912#011validation-auc:0.72899
# [129]#011train-auc:0.81919#011validation-auc:0.72900
# [130]#011train-auc:0.81934#011validation-auc:0.72907
# [131]#011train-auc:0.81975#011validation-auc:0.72913
# [132]#011train-auc:0.82008#011validation-auc:0.72918
# [133]#011train-auc:0.82020#011validation-auc:0.72921
# [134]#011train-auc:0.82036#011validation-auc:0.72937
# [135]#011train-auc:0.82057#011validation-auc:0.72947
# [136]#011train-auc:0.82081#011validation-auc:0.72951
# [137]#011train-auc:0.82102#011validation-auc:0.72953
# [138]#011train-auc:0.82115#011validation-auc:0.72951
# [139]#011train-auc:0.82130#011validation-auc:0.72953
# [140]#011train-auc:0.82148#011validation-auc:0.72956
# [141]#011train-auc:0.82154#011validation-auc:0.72959
# [142]#011train-auc:0.82164#011validation-auc:0.72958
# [143]#011train-auc:0.82173#011validation-auc:0.72963
# [144]#011train-auc:0.82178#011validation-auc:0.72966
# [145]#011train-auc:0.82181#011validation-auc:0.72967
# [146]#011train-auc:0.82186#011validation-auc:0.72968
# [147]#011train-auc:0.82190#011validation-auc:0.72968
# [148]#011train-auc:0.82211#011validation-auc:0.72973
# [149]#011train-auc:0.82215#011validation-auc:0.72973
# [150]#011train-auc:0.82245#011validation-auc:0.72977
# [151]#011train-auc:0.82249#011validation-auc:0.72982
# [152]#011train-auc:0.82254#011validation-auc:0.72982
# [153]#011train-auc:0.82260#011validation-auc:0.72981
# [154]#011train-auc:0.82296#011validation-auc:0.72991
# [155]#011train-auc:0.82305#011validation-auc:0.72992
# [156]#011train-auc:0.82338#011validation-auc:0.72992
# [157]#011train-auc:0.82340#011validation-auc:0.72994
# [158]#011train-auc:0.82354#011validation-auc:0.72992
# [159]#011train-auc:0.82378#011validation-auc:0.72998
# [160]#011train-auc:0.82385#011validation-auc:0.73001
# [161]#011train-auc:0.82425#011validation-auc:0.73011
# [162]#011train-auc:0.82428#011validation-auc:0.73012
# [163]#011train-auc:0.82447#011validation-auc:0.73021
# [164]#011train-auc:0.82485#011validation-auc:0.73049
# [165]#011train-auc:0.82491#011validation-auc:0.73050
# [166]#011train-auc:0.82505#011validation-auc:0.73057
# [167]#011train-auc:0.82513#011validation-auc:0.73056
# [168]#011train-auc:0.82543#011validation-auc:0.73057
# [169]#011train-auc:0.82586#011validation-auc:0.73075
# [170]#011train-auc:0.82607#011validation-auc:0.73087
# [171]#011train-auc:0.82650#011validation-auc:0.73094
# [172]#011train-auc:0.82690#011validation-auc:0.73107
# [173]#011train-auc:0.82723#011validation-auc:0.73114
# [174]#011train-auc:0.82733#011validation-auc:0.73113
# [175]#011train-auc:0.82741#011validation-auc:0.73115
# [176]#011train-auc:0.82748#011validation-auc:0.73113
# [177]#011train-auc:0.82799#011validation-auc:0.73134
# [178]#011train-auc:0.82803#011validation-auc:0.73135
# [179]#011train-auc:0.82825#011validation-auc:0.73138
# [180]#011train-auc:0.82838#011validation-auc:0.73140
# [181]#011train-auc:0.82839#011validation-auc:0.73140
# [182]#011train-auc:0.82863#011validation-auc:0.73148
# [183]#011train-auc:0.82870#011validation-auc:0.73147
# [184]#011train-auc:0.82881#011validation-auc:0.73146
# [185]#011train-auc:0.82900#011validation-auc:0.73149
# [186]#011train-auc:0.82914#011validation-auc:0.73153
# [187]#011train-auc:0.82921#011validation-auc:0.73154
# [188]#011train-auc:0.82941#011validation-auc:0.73154
# [189]#011train-auc:0.82961#011validation-auc:0.73164
# [190]#011train-auc:0.82969#011validation-auc:0.73163
# [191]#011train-auc:0.82973#011validation-auc:0.73164
# [192]#011train-auc:0.82999#011validation-auc:0.73179
# [193]#011train-auc:0.83001#011validation-auc:0.73180
# [194]#011train-auc:0.83015#011validation-auc:0.73183
# [195]#011train-auc:0.83023#011validation-auc:0.73182
# [196]#011train-auc:0.83028#011validation-auc:0.73181
# [197]#011train-auc:0.83032#011validation-auc:0.73182
# [198]#011train-auc:0.83035#011validation-auc:0.73180
# [199]#011train-auc:0.83043#011validation-auc:0.73180
# [200]#011train-auc:0.83044#011validation-auc:0.73180
# [201]#011train-auc:0.83049#011validation-auc:0.73179
# [202]#011train-auc:0.83051#011validation-auc:0.73178
# [203]#011train-auc:0.83057#011validation-auc:0.73177
# [204]#011train-auc:0.83059#011validation-auc:0.73178
# [205]#011train-auc:0.83080#011validation-auc:0.73182
# [206]#011train-auc:0.83093#011validation-auc:0.73182
# [207]#011train-auc:0.83097#011validation-auc:0.73181
# [208]#011train-auc:0.83105#011validation-auc:0.73185
# [209]#011train-auc:0.83122#011validation-auc:0.73183
# [210]#011train-auc:0.83163#011validation-auc:0.73196
# [211]#011train-auc:0.83172#011validation-auc:0.73196
# [212]#011train-auc:0.83182#011validation-auc:0.73198
# [213]#011train-auc:0.83201#011validation-auc:0.73205
# [214]#011train-auc:0.83202#011validation-auc:0.73205
# [215]#011train-auc:0.83217#011validation-auc:0.73211
# [216]#011train-auc:0.83234#011validation-auc:0.73213
# [217]#011train-auc:0.83269#011validation-auc:0.73223
# [218]#011train-auc:0.83274#011validation-auc:0.73223
# [219]#011train-auc:0.83276#011validation-auc:0.73224
# [220]#011train-auc:0.83286#011validation-auc:0.73224
# [221]#011train-auc:0.83300#011validation-auc:0.73232
# [222]#011train-auc:0.83310#011validation-auc:0.73232
# [223]#011train-auc:0.83317#011validation-auc:0.73231
# [224]#011train-auc:0.83343#011validation-auc:0.73250
# [225]#011train-auc:0.83354#011validation-auc:0.73250
# [226]#011train-auc:0.83361#011validation-auc:0.73251
# [227]#011train-auc:0.83367#011validation-auc:0.73250
# [228]#011train-auc:0.83380#011validation-auc:0.73250
# [229]#011train-auc:0.83391#011validation-auc:0.73249
# [230]#011train-auc:0.83426#011validation-auc:0.73263
# [231]#011train-auc:0.83435#011validation-auc:0.73264
# [232]#011train-auc:0.83437#011validation-auc:0.73264
# [233]#011train-auc:0.83452#011validation-auc:0.73262
# [234]#011train-auc:0.83462#011validation-auc:0.73264
# [235]#011train-auc:0.83483#011validation-auc:0.73269
# [236]#011train-auc:0.83489#011validation-auc:0.73270
# [237]#011train-auc:0.83514#011validation-auc:0.73275
# [238]#011train-auc:0.83519#011validation-auc:0.73275
# [239]#011train-auc:0.83521#011validation-auc:0.73275
# [240]#011train-auc:0.83522#011validation-auc:0.73275
# [241]#011train-auc:0.83522#011validation-auc:0.73275
# [242]#011train-auc:0.83522#011validation-auc:0.73275
# [243]#011train-auc:0.83537#011validation-auc:0.73276
# [244]#011train-auc:0.83548#011validation-auc:0.73277
# [245]#011train-auc:0.83550#011validation-auc:0.73276
# [246]#011train-auc:0.83564#011validation-auc:0.73276
# [247]#011train-auc:0.83580#011validation-auc:0.73273
# [248]#011train-auc:0.83583#011validation-auc:0.73274
# [249]#011train-auc:0.83609#011validation-auc:0.73274
# [250]#011train-auc:0.83616#011validation-auc:0.73274
# [251]#011train-auc:0.83621#011validation-auc:0.73275
# [252]#011train-auc:0.83630#011validation-auc:0.73273
# [253]#011train-auc:0.83636#011validation-auc:0.73274
# [254]#011train-auc:0.83639#011validation-auc:0.73274
# [255]#011train-auc:0.83664#011validation-auc:0.73282
# [256]#011train-auc:0.83664#011validation-auc:0.73282
# [257]#011train-auc:0.83665#011validation-auc:0.73281
# [258]#011train-auc:0.83665#011validation-auc:0.73281
# [259]#011train-auc:0.83681#011validation-auc:0.73287
# [260]#011train-auc:0.83694#011validation-auc:0.73289
# [261]#011train-auc:0.83694#011validation-auc:0.73289
# [262]#011train-auc:0.83711#011validation-auc:0.73288
# [263]#011train-auc:0.83711#011validation-auc:0.73288
# [264]#011train-auc:0.83720#011validation-auc:0.73288
# [265]#011train-auc:0.83721#011validation-auc:0.73289
# [266]#011train-auc:0.83736#011validation-auc:0.73290
# [267]#011train-auc:0.83740#011validation-auc:0.73289
# [268]#011train-auc:0.83740#011validation-auc:0.73289
# [269]#011train-auc:0.83746#011validation-auc:0.73289
# [270]#011train-auc:0.83749#011validation-auc:0.73288
# [271]#011train-auc:0.83749#011validation-auc:0.73288
# [272]#011train-auc:0.83754#011validation-auc:0.73286
# [273]#011train-auc:0.83761#011validation-auc:0.73287
# [274]#011train-auc:0.83774#011validation-auc:0.73289
# [275]#011train-auc:0.83785#011validation-auc:0.73288
# [276]#011train-auc:0.83791#011validation-auc:0.73289
# [277]#011train-auc:0.83796#011validation-auc:0.73289
# [278]#011train-auc:0.83796#011validation-auc:0.73289
# [279]#011train-auc:0.83799#011validation-auc:0.73290
# [280]#011train-auc:0.83810#011validation-auc:0.73292
# [281]#011train-auc:0.83812#011validation-auc:0.73292
# [282]#011train-auc:0.83815#011validation-auc:0.73293
# [283]#011train-auc:0.83830#011validation-auc:0.73296
# [284]#011train-auc:0.83849#011validation-auc:0.73301
# [285]#011train-auc:0.83871#011validation-auc:0.73305
# [286]#011train-auc:0.83890#011validation-auc:0.73304
# [287]#011train-auc:0.83893#011validation-auc:0.73306
# [288]#011train-auc:0.83898#011validation-auc:0.73308
# [289]#011train-auc:0.83900#011validation-auc:0.73308
# [290]#011train-auc:0.83900#011validation-auc:0.73308
# [291]#011train-auc:0.83907#011validation-auc:0.73310
# [292]#011train-auc:0.83912#011validation-auc:0.73310
# [293]#011train-auc:0.83913#011validation-auc:0.73310
# [294]#011train-auc:0.83939#011validation-auc:0.73328
# [295]#011train-auc:0.83944#011validation-auc:0.73332
# [296]#011train-auc:0.83949#011validation-auc:0.73332
# [297]#011train-auc:0.83949#011validation-auc:0.73332
# [298]#011train-auc:0.83949#011validation-auc:0.73332
# [299]#011train-auc:0.83964#011validation-auc:0.73336
# [300]#011train-auc:0.83979#011validation-auc:0.73336
# [301]#011train-auc:0.83984#011validation-auc:0.73336
# [302]#011train-auc:0.83984#011validation-auc:0.73336
# [303]#011train-auc:0.83991#011validation-auc:0.73337
# [304]#011train-auc:0.84000#011validation-auc:0.73337
# [305]#011train-auc:0.84032#011validation-auc:0.73346
# [306]#011train-auc:0.84035#011validation-auc:0.73346
# [307]#011train-auc:0.84036#011validation-auc:0.73345
# [308]#011train-auc:0.84049#011validation-auc:0.73344
# [309]#011train-auc:0.84058#011validation-auc:0.73348
# [310]#011train-auc:0.84061#011validation-auc:0.73348
# [311]#011train-auc:0.84063#011validation-auc:0.73348
# [312]#011train-auc:0.84063#011validation-auc:0.73348
# [313]#011train-auc:0.84063#011validation-auc:0.73348
# [314]#011train-auc:0.84073#011validation-auc:0.73349
# [315]#011train-auc:0.84081#011validation-auc:0.73349
# [316]#011train-auc:0.84089#011validation-auc:0.73345
# [317]#011train-auc:0.84091#011validation-auc:0.73345
# [318]#011train-auc:0.84098#011validation-auc:0.73346
# [319]#011train-auc:0.84100#011validation-auc:0.73347
# [320]#011train-auc:0.84100#011validation-auc:0.73347
# [321]#011train-auc:0.84116#011validation-auc:0.73350
# [322]#011train-auc:0.84121#011validation-auc:0.73348
# [323]#011train-auc:0.84123#011validation-auc:0.73348
# [324]#011train-auc:0.84131#011validation-auc:0.73346
# [325]#011train-auc:0.84137#011validation-auc:0.73346
# [326]#011train-auc:0.84144#011validation-auc:0.73346
# [327]#011train-auc:0.84154#011validation-auc:0.73348
# [328]#011train-auc:0.84157#011validation-auc:0.73347
# [329]#011train-auc:0.84166#011validation-auc:0.73346
# [330]#011train-auc:0.84168#011validation-auc:0.73346
# [331]#011train-auc:0.84168#011validation-auc:0.73346
# [332]#011train-auc:0.84173#011validation-auc:0.73348
# [333]#011train-auc:0.84189#011validation-auc:0.73353
# [334]#011train-auc:0.84201#011validation-auc:0.73352
# [335]#011train-auc:0.84203#011validation-auc:0.73352
# [336]#011train-auc:0.84203#011validation-auc:0.73352
# [337]#011train-auc:0.84222#011validation-auc:0.73357
# [338]#011train-auc:0.84222#011validation-auc:0.73357
# [339]#011train-auc:0.84234#011validation-auc:0.73359
# [340]#011train-auc:0.84262#011validation-auc:0.73361
# [341]#011train-auc:0.84262#011validation-auc:0.73361
# [342]#011train-auc:0.84262#011validation-auc:0.73361
# [343]#011train-auc:0.84263#011validation-auc:0.73360
# [344]#011train-auc:0.84265#011validation-auc:0.73360
# [345]#011train-auc:0.84268#011validation-auc:0.73360
# [346]#011train-auc:0.84277#011validation-auc:0.73363
# [347]#011train-auc:0.84280#011validation-auc:0.73362
# [348]#011train-auc:0.84281#011validation-auc:0.73361
# [349]#011train-auc:0.84294#011validation-auc:0.73364
# [350]#011train-auc:0.84296#011validation-auc:0.73363
# [351]#011train-auc:0.84298#011validation-auc:0.73364
# [352]#011train-auc:0.84301#011validation-auc:0.73365
# [353]#011train-auc:0.84302#011validation-auc:0.73365
# [354]#011train-auc:0.84305#011validation-auc:0.73366
# [355]#011train-auc:0.84318#011validation-auc:0.73364
# [356]#011train-auc:0.84334#011validation-auc:0.73366
# [357]#011train-auc:0.84338#011validation-auc:0.73365
# [358]#011train-auc:0.84344#011validation-auc:0.73365
# [359]#011train-auc:0.84347#011validation-auc:0.73364
# [360]#011train-auc:0.84351#011validation-auc:0.73364
# [361]#011train-auc:0.84372#011validation-auc:0.73366
# [362]#011train-auc:0.84373#011validation-auc:0.73366
# [363]#011train-auc:0.84381#011validation-auc:0.73366
# [364]#011train-auc:0.84384#011validation-auc:0.73368
# [365]#011train-auc:0.84387#011validation-auc:0.73369
# [366]#011train-auc:0.84396#011validation-auc:0.73367
# [367]#011train-auc:0.84408#011validation-auc:0.73371
# [368]#011train-auc:0.84410#011validation-auc:0.73370
# [369]#011train-auc:0.84410#011validation-auc:0.73370
# [370]#011train-auc:0.84413#011validation-auc:0.73372
# [371]#011train-auc:0.84413#011validation-auc:0.73372
# [372]#011train-auc:0.84415#011validation-auc:0.73371
# [373]#011train-auc:0.84421#011validation-auc:0.73372
# [374]#011train-auc:0.84423#011validation-auc:0.73374
# [375]#011train-auc:0.84427#011validation-auc:0.73377
# [376]#011train-auc:0.84429#011validation-auc:0.73377
# [377]#011train-auc:0.84432#011validation-auc:0.73376
# [378]#011train-auc:0.84442#011validation-auc:0.73379
# [379]#011train-auc:0.84443#011validation-auc:0.73379
# [380]#011train-auc:0.84444#011validation-auc:0.73378
# [381]#011train-auc:0.84446#011validation-auc:0.73378
# [382]#011train-auc:0.84450#011validation-auc:0.73377
# [383]#011train-auc:0.84452#011validation-auc:0.73377
# [384]#011train-auc:0.84455#011validation-auc:0.73376
# [385]#011train-auc:0.84455#011validation-auc:0.73376
# [386]#011train-auc:0.84458#011validation-auc:0.73376
# [387]#011train-auc:0.84458#011validation-auc:0.73376
# [388]#011train-auc:0.84466#011validation-auc:0.73379
# [389]#011train-auc:0.84466#011validation-auc:0.73379
# [390]#011train-auc:0.84472#011validation-auc:0.73380
# [391]#011train-auc:0.84481#011validation-auc:0.73381
# [392]#011train-auc:0.84483#011validation-auc:0.73381
# [393]#011train-auc:0.84486#011validation-auc:0.73381
# [394]#011train-auc:0.84492#011validation-auc:0.73383
# [395]#011train-auc:0.84492#011validation-auc:0.73383
# [396]#011train-auc:0.84492#011validation-auc:0.73383
# [397]#011train-auc:0.84504#011validation-auc:0.73386
# [398]#011train-auc:0.84506#011validation-auc:0.73384
# [399]#011train-auc:0.84506#011validation-auc:0.73384
# [400]#011train-auc:0.84513#011validation-auc:0.73384
# [401]#011train-auc:0.84516#011validation-auc:0.73384
# [402]#011train-auc:0.84516#011validation-auc:0.73384
# [403]#011train-auc:0.84518#011validation-auc:0.73385
# [404]#011train-auc:0.84518#011validation-auc:0.73385
# [405]#011train-auc:0.84518#011validation-auc:0.73385
# [406]#011train-auc:0.84529#011validation-auc:0.73386
# [407]#011train-auc:0.84529#011validation-auc:0.73386
# [408]#011train-auc:0.84529#011validation-auc:0.73386
# [409]#011train-auc:0.84533#011validation-auc:0.73387
# [410]#011train-auc:0.84536#011validation-auc:0.73386
# [411]#011train-auc:0.84538#011validation-auc:0.73386
# [412]#011train-auc:0.84538#011validation-auc:0.73386
# [413]#011train-auc:0.84542#011validation-auc:0.73385
# [414]#011train-auc:0.84554#011validation-auc:0.73387
# [415]#011train-auc:0.84564#011validation-auc:0.73388
# [416]#011train-auc:0.84568#011validation-auc:0.73388
# [417]#011train-auc:0.84575#011validation-auc:0.73388
# [418]#011train-auc:0.84577#011validation-auc:0.73388
# [419]#011train-auc:0.84587#011validation-auc:0.73390
# [420]#011train-auc:0.84596#011validation-auc:0.73388
# [421]#011train-auc:0.84605#011validation-auc:0.73388
# [422]#011train-auc:0.84608#011validation-auc:0.73389
# [423]#011train-auc:0.84612#011validation-auc:0.73387
# [424]#011train-auc:0.84615#011validation-auc:0.73386
# [425]#011train-auc:0.84615#011validation-auc:0.73386
# [426]#011train-auc:0.84615#011validation-auc:0.73386
# [427]#011train-auc:0.84617#011validation-auc:0.73386
# [428]#011train-auc:0.84633#011validation-auc:0.73391
# [429]#011train-auc:0.84638#011validation-auc:0.73391
# [430]#011train-auc:0.84644#011validation-auc:0.73392
# [431]#011train-auc:0.84648#011validation-auc:0.73391
# [432]#011train-auc:0.84650#011validation-auc:0.73391
# [433]#011train-auc:0.84666#011validation-auc:0.73387
# [434]#011train-auc:0.84671#011validation-auc:0.73385
# [435]#011train-auc:0.84679#011validation-auc:0.73386
# [436]#011train-auc:0.84679#011validation-auc:0.73386
# [437]#011train-auc:0.84690#011validation-auc:0.73390
# [438]#011train-auc:0.84690#011validation-auc:0.73390
# [439]#011train-auc:0.84690#011validation-auc:0.73390
# [440]#011train-auc:0.84696#011validation-auc:0.73390
# [441]#011train-auc:0.84703#011validation-auc:0.73391
# [442]#011train-auc:0.84712#011validation-auc:0.73393
# [443]#011train-auc:0.84714#011validation-auc:0.73394
# [444]#011train-auc:0.84715#011validation-auc:0.73394
# [445]#011train-auc:0.84715#011validation-auc:0.73394
# [446]#011train-auc:0.84725#011validation-auc:0.73395
# [447]#011train-auc:0.84727#011validation-auc:0.73394
# [448]#011train-auc:0.84730#011validation-auc:0.73394
# [449]#011train-auc:0.84738#011validation-auc:0.73395
# [450]#011train-auc:0.84740#011validation-auc:0.73394
# [451]#011train-auc:0.84740#011validation-auc:0.73394
# [452]#011train-auc:0.84740#011validation-auc:0.73394
# [453]#011train-auc:0.84744#011validation-auc:0.73394
# [454]#011train-auc:0.84745#011validation-auc:0.73394
# [455]#011train-auc:0.84745#011validation-auc:0.73394
# [456]#011train-auc:0.84766#011validation-auc:0.73400
# [457]#011train-auc:0.84766#011validation-auc:0.73400
# [458]#011train-auc:0.84768#011validation-auc:0.73400
# [459]#011train-auc:0.84768#011validation-auc:0.73400
# [460]#011train-auc:0.84774#011validation-auc:0.73400
# [461]#011train-auc:0.84776#011validation-auc:0.73401
# [462]#011train-auc:0.84778#011validation-auc:0.73400
# [463]#011train-auc:0.84786#011validation-auc:0.73401
# [464]#011train-auc:0.84793#011validation-auc:0.73404
# [465]#011train-auc:0.84793#011validation-auc:0.73404
# [466]#011train-auc:0.84805#011validation-auc:0.73405
# [467]#011train-auc:0.84807#011validation-auc:0.73404
# [468]#011train-auc:0.84809#011validation-auc:0.73404
# [469]#011train-auc:0.84818#011validation-auc:0.73405
# [470]#011train-auc:0.84829#011validation-auc:0.73406
# [471]#011train-auc:0.84832#011validation-auc:0.73405
# [472]#011train-auc:0.84832#011validation-auc:0.73405
# [473]#011train-auc:0.84834#011validation-auc:0.73404
# [474]#011train-auc:0.84835#011validation-auc:0.73403
# [475]#011train-auc:0.84840#011validation-auc:0.73403
# [476]#011train-auc:0.84847#011validation-auc:0.73402
# [477]#011train-auc:0.84858#011validation-auc:0.73403
# [478]#011train-auc:0.84859#011validation-auc:0.73403
# [479]#011train-auc:0.84867#011validation-auc:0.73407
# [480]#011train-auc:0.84867#011validation-auc:0.73407
# [481]#011train-auc:0.84870#011validation-auc:0.73406
# [482]#011train-auc:0.84885#011validation-auc:0.73410
# [483]#011train-auc:0.84885#011validation-auc:0.73410
# [484]#011train-auc:0.84889#011validation-auc:0.73411
# [485]#011train-auc:0.84897#011validation-auc:0.73412
# [486]#011train-auc:0.84899#011validation-auc:0.73412
# [487]#011train-auc:0.84902#011validation-auc:0.73412
# [488]#011train-auc:0.84912#011validation-auc:0.73413
# [489]#011train-auc:0.84915#011validation-auc:0.73414
# [490]#011train-auc:0.84915#011validation-auc:0.73414
# [491]#011train-auc:0.84930#011validation-auc:0.73417
# [492]#011train-auc:0.84932#011validation-auc:0.73417
# [493]#011train-auc:0.84932#011validation-auc:0.73417
# [494]#011train-auc:0.84934#011validation-auc:0.73418
# [495]#011train-auc:0.84936#011validation-auc:0.73417
# [496]#011train-auc:0.84938#011validation-auc:0.73417
# [497]#011train-auc:0.84938#011validation-auc:0.73417
# [498]#011train-auc:0.84944#011validation-auc:0.73419
# [499]#011train-auc:0.84944#011validation-auc:0.73419
# Training seconds: 537
# Billable seconds: 537
# ...................[2020-07-19:10:55:29:INFO] No GPUs detected (normal if no gpus installed)
# [2020-07-19:10:55:29:INFO] No GPUs detected (normal if no gpus installed)
# [2020-07-19:10:55:29:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# [2020-07-19:10:55:29:INFO] No GPUs detected (normal if no gpus installed)
# [2020-07-19:10:55:29:INFO] No GPUs detected (normal if no gpus installed)
# [2020-07-19:10:55:29:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# [2020-07-19 10:55:29 +0000] [13] [INFO] Starting gunicorn 19.10.0
# [2020-07-19 10:55:29 +0000] [13] [INFO] Listening at: unix:/tmp/gunicorn.sock (13)
# [2020-07-19 10:55:29 +0000] [13] [INFO] Using worker: gevent
# [2020-07-19 10:55:29 +0000] [18] [INFO] Booting worker with pid: 18
# }
#
#
# [2020-07-19 10:55:29 +0000] [13] [INFO] Starting gunicorn 19.10.0
# [2020-07-19 10:55:29 +0000] [13] [INFO] Listening at: unix:/tmp/gunicorn.sock (13)
# [2020-07-19 10:55:29 +0000] [13] [INFO] Using worker: gevent
# [2020-07-19 10:55:29 +0000] [18] [INFO] Booting worker with pid: 18
# [2020-07-19 10:55:29 +0000] [19] [INFO] Booting worker with pid: 19
# [2020-07-19 10:55:29 +0000] [19] [INFO] Booting worker with pid: 19
# [2020-07-19:10:55:34:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [19/Jul/2020:10:55:34 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2020-07-19:10:55:34:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [19/Jul/2020:10:55:34 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2020-07-19:10:55:34:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [19/Jul/2020:10:55:34 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2020-07-19:10:55:34:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [19/Jul/2020:10:55:34 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# 2020-07-19T10:55:34.198:[sagemaker logs]: MaxConcurrentTransforms=2, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2020-07-19:10:55:35:INFO] Determined delimiter of CSV input is ','
# [2020-07-19:10:55:35:INFO] Determined delimiter of CSV input is ','
# [2020-07-19:10:55:35:INFO] Determined delimiter of CSV input is ','
# [2020-07-19:10:55:35:INFO] Determined delimiter of CSV input is ','
# [2020-07-19:10:55:40:INFO] Determined delimiter of CSV input is ','
# [2020-07-19:10:55:40:INFO] Determined delimiter of CSV input is ','
# [2020-07-19:10:55:40:INFO] Determined delimiter of CSV input is ','
# [2020-07-19:10:55:40:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [19/Jul/2020:10:55:43 +0000] "POST /invocations HTTP/1.1" 200 361736 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [19/Jul/2020:10:55:43 +0000] "POST /invocations HTTP/1.1" 200 349991 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [19/Jul/2020:10:55:43 +0000] "POST /invocations HTTP/1.1" 200 361736 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [19/Jul/2020:10:55:43 +0000] "POST /invocations HTTP/1.1" 200 349991 "-" "Go-http-client/1.1"
#
# download: s3://sagemaker-eu-west-1-019518462631/sagemaker-xgboost-200719-1001-016-cacc2-2020-07-19-10-52-31-613/test-2.csv.out to ../data/500000/test-2.csv.out
# Accuracy: 0.677160
# Recal:    0.726896
# ROC AUC:  0.674253
# CPU times: user 793 ms, sys: 55.5 ms, total: 848 ms
# Wall time: 3min 44s

# %% [markdown]
# After testing 30 different combinations, the best XGBoost model achieved an AUC of **0.73419** on the validation set. Compared with the initial XGBoost model (AUC 0.71918), this is an improvement of 0.01501 over the initial XGBoost model.
#
# On the test set, the final XGBoost model achieven an AUC of **0.674253** on the test set (which is an improvement of 0.011264 compared to the initial model).
